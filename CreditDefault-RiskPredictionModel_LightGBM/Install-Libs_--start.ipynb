# %%
# install libraries
# %pip install category_encoders==2.5.0
# %pip install hyperopt==0.2.7
# %pip install lightgbm==3.3.0
# %pip install matplotlib==3.5.1
# %pip install numpy==1.22.4
# %pip install pandas==1.3.0
# %pip install scikit_learn==1.1.2
# %pip install seaborn==0.12.0
# %pip install shap==0.40.0
# Out:
# Collecting category_encoders==2.5.0
#   Downloading category_encoders-2.5.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 10.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0.5 in /home/labuser/.local/lib/python3.8/site-packages (from category_encoders==2.5.0) (1.3.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /home/labuser/.local/lib/python3.8/site-packages (from category_encoders==2.5.0) (0.12.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/labuser/.local/lib/python3.8/site-packages (from category_encoders==2.5.0) (1.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from category_encoders==2.5.0) (1.7.0)
# Requirement already satisfied: patsy>=0.5.1 in /home/labuser/.local/lib/python3.8/site-packages (from category_encoders==2.5.0) (0.5.2)
# Requirement already satisfied: numpy>=1.14.0 in /home/labuser/.local/lib/python3.8/site-packages (from category_encoders==2.5.0) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas>=1.0.5->category_encoders==2.5.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=1.0.5->category_encoders==2.5.0) (2019.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders==2.5.0) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders==2.5.0) (1.1.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.1->category_encoders==2.5.0) (1.14.0)
# Installing collected packages: category-encoders
#   Attempting uninstall: category-encoders
#     Found existing installation: category-encoders 2.4.0
#     Uninstalling category-encoders-2.4.0:
#       Successfully uninstalled category-encoders-2.4.0
# Successfully installed category-encoders-2.5.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting hyperopt==0.2.7
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 32.8 MB/s eta 0:00:01
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from hyperopt==0.2.7) (1.14.0)
# Requirement already satisfied: networkx>=2.2 in /home/labuser/.local/lib/python3.8/site-packages (from hyperopt==0.2.7) (2.3)
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 108.6 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from hyperopt==0.2.7) (1.7.0)
# Requirement already satisfied: cloudpickle in /home/labuser/.local/lib/python3.8/site-packages (from hyperopt==0.2.7) (2.1.0)
# Requirement already satisfied: tqdm in /home/labuser/.local/lib/python3.8/site-packages (from hyperopt==0.2.7) (4.64.0)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from hyperopt==0.2.7) (1.21.1)
# Requirement already satisfied: future in /home/labuser/.local/lib/python3.8/site-packages (from hyperopt==0.2.7) (0.18.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/labuser/.local/lib/python3.8/site-packages (from networkx>=2.2->hyperopt==0.2.7) (5.1.1)
# Installing collected packages: py4j, hyperopt
#   WARNING: The script hyperopt-mongo-worker is installed in '/home/labuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed hyperopt-0.2.7 py4j-0.10.9.7
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lightgbm==3.3.0 in /home/labuser/.local/lib/python3.8/site-packages (3.3.0)
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from lightgbm==3.3.0) (1.7.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from lightgbm==3.3.0) (0.34.2)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from lightgbm==3.3.0) (1.21.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/labuser/.local/lib/python3.8/site-packages (from lightgbm==3.3.0) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.0) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib==3.5.1
#   Downloading matplotlib-3.5.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 36.7 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib==3.5.1) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib==3.5.1) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib==3.5.1) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib==3.5.1) (1.21.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib==3.5.1) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib==3.5.1) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib==3.5.1) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.2-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 91.9 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib==3.5.1) (1.14.0)
# Installing collected packages: fonttools, matplotlib
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/labuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:
#       Successfully uninstalled matplotlib-3.4.3
# Successfully installed fonttools-4.39.2 matplotlib-3.5.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting numpy==1.22.4
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 21.7 MB/s eta 0:00:01
# ERROR: visions 0.7.4 has requirement networkx>=2.4, but you'll have networkx 2.3 which is incompatible.
# ERROR: numba 0.55.1 has requirement numpy<1.22,>=1.18, but you'll have numpy 1.22.4 which is incompatible.
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.1
#     Uninstalling numpy-1.21.1:
#       Successfully uninstalled numpy-1.21.1
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home/labuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed numpy-1.22.4
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas==1.3.0 in /home/labuser/.local/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas==1.3.0) (2019.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas==1.3.0) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas==1.3.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.0) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting scikit_learn==1.1.2
#   Downloading scikit_learn-1.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 74 kB/s s eta 0:00:01
# Requirement already satisfied: joblib>=1.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.1.2) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.1.2) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.1.2) (1.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.1.2) (3.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed scikit-learn-1.1.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting seaborn==0.12.0
#   Downloading seaborn-0.12.0-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 30.2 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.25 in /home/labuser/.local/lib/python3.8/site-packages (from seaborn==0.12.0) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /home/labuser/.local/lib/python3.8/site-packages (from seaborn==0.12.0) (1.22.4)
# Requirement already satisfied: matplotlib>=3.1 in /home/labuser/.local/lib/python3.8/site-packages (from seaborn==0.12.0) (3.5.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.25->seaborn==0.12.0) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas>=0.25->seaborn==0.12.0) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn==0.12.0) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn==0.12.0) (4.39.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn==0.12.0) (9.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn==0.12.0) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn==0.12.0) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=3.1->seaborn==0.12.0) (1.4.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25->seaborn==0.12.0) (1.14.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# Successfully installed seaborn-0.12.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: shap==0.40.0 in /home/labuser/.local/lib/python3.8/site-packages (0.40.0)
# Requirement already satisfied: pandas in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.3.0)
# Requirement already satisfied: scikit-learn in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.1.2)
# Requirement already satisfied: slicer==0.0.7 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (0.0.7)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.22.4)
# Requirement already satisfied: cloudpickle in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (2.1.0)
# Requirement already satisfied: tqdm>4.25.0 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (4.64.0)
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.7.0)
# Requirement already satisfied: numba in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (0.55.1)
# Requirement already satisfied: packaging>20.9 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (21.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas->shap==0.40.0) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas->shap==0.40.0) (2.8.2)
# Requirement already satisfied: joblib>=1.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn->shap==0.40.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn->shap==0.40.0) (3.1.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba->shap==0.40.0) (45.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/labuser/.local/lib/python3.8/site-packages (from numba->shap==0.40.0) (0.38.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/labuser/.local/lib/python3.8/site-packages (from packaging>20.9->shap==0.40.0) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->shap==0.40.0) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numba==0.53.1
# Out:
# Collecting numba==0.53.1
#   Downloading numba-0.53.1-cp38-cp38-manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 29.8 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba==0.53.1) (45.2.0)
# Requirement already satisfied: numpy>=1.15 in /home/labuser/.local/lib/python3.8/site-packages (from numba==0.53.1) (1.22.4)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp38-cp38-manylinux2010_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 92.6 MB/s eta 0:00:01
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.38.1
#     Uninstalling llvmlite-0.38.1:
#       Successfully uninstalled llvmlite-0.38.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.55.1
#     Uninstalling numba-0.55.1:
#       Successfully uninstalled numba-0.55.1
# Successfully installed llvmlite-0.36.0 numba-0.53.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")
import os
path = os.getcwd()
import sys
sys.path.append("")
from utils import *

import pandas as pd
import numpy as np

import random

import category_encoders as ce
import lightgbm as lgb
from lightgbm import LGBMClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
import bisect

from sklearn.preprocessing import OneHotEncoder

from hyperopt import fmin, tpe, hp, anneal, Trials

import os
import gc

import datetime

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.float_format', lambda x: '%.3f' % x)
# %load_ext autoreload
# %autoreload 2
